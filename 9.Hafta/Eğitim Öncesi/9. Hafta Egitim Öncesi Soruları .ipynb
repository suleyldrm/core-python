# %% [markdown]
# # Problem 1
# Vehicle sınıfından miras alan bir Bus sınıfı oluşturun. Bus.seating_capacity()'nin kapasite bağımsız değişkenine varsayılan olarak 50 değerini verin.
#
# ```
# Output:
# > The seating capacity of a bus is 50 passengers
# ```

# %%
class Vehicle:
    def __init__(self,capacity):
        class bus(Vehicle):
             def __init__(self,name,capaciy=50):
                self.capaciy=capacity
                return f"The Seating capacity of a {self.name}is {capacity} passengers."
       
bus1=bus("Nissan",10)
print(bus1.capacity)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 8
#       5                 self.capaciy=capacity
#       6                 return f"The Seating capacity of a {self.name}is {capacity} passengers."
# ----> 8 bus1=bus("Nissan",10)
#       9 print(bus1.capacity)
#
# TypeError: Vehicle.__init__() takes 2 positional arguments but 3 were given

# %% [markdown]
# # Problem 2
#
#
# School_bus'ın aynı zamanda Vehicle sınıfının bir örneği olup olmadığını belirleyiniz.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
