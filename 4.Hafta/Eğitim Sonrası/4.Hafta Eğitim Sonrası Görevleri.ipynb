# %% [markdown]
# # Problem 1
# `ogrenciler` adında bir sözlük oluşturunuz. Kullanıcıdan döngü yardımıyla 3 öğrenci için veri girmesini isteyerek öğrencilerin sırasıyla okul numarası, isim, soy isim, telefon numarası ve doğum tarihi bilgilerini alınız. Aldığınız öğrenci bilgilerini yine aynı döngü yardımıyla `ogrenciler` adındaki sözlükte saklayınız. Daha sonra öğrenci bilgilerinin bulunduğu sözlük yapısını ekrana bastırınız.

# %%
ogrenciler={}

for i in range(1,4):
    okulNo=input("okul numaranızı giriniz: ")
    isim=input("isminizi giriniz: ")
    soyIsım=input("soyisminizi giriniz: ")
    telefon=input("telefon numaranızı giriniz: ")
    dogumTarihi=input("doğum tarihinizi giriniz: ")

    ogrenciler[i]={
        "No": okulNo,
        "İsim": isim,
        "Soy isim": soyIsım,
        "Dogum Tarihi": dogumTarihi
    }

print(ogrenciler)
# Out:
# {1: {'No': '', 'İsim': '', 'Soy isim': '', 'Dogum Tarihi': ''}, 2: {'No': '', 'İsim': '', 'Soy isim': '', 'Dogum Tarihi': ''}, 3: {'No': '', 'İsim': '', 'Soy isim': '', 'Dogum Tarihi': ''}}

# %% [markdown]
# # Problem 2
#
# ### a - Biraz ısınarak başlayalım!
#
# ```
# numbers = [5,10,10,15,15,15,20,20,20,20]
# ```
#
# Yukarıda `numbers` adında 10 elemanlı bir liste verilmiştir. Bu listenin her elemanını kontrol eden ve tekrar eden elemanları bir kez olacak şekilde başka bir listeye kopyalayan bir program yazınız. Son olarak oluşturduğunuz listeyi ekrana bastırınız.
#
#
#
#
# ```
# >Output
# [5, 10, 15, 20]
# ```

# %%
numbers=[5,10,10,15,15,15,20,20,20,20]
birTane=[]
for number in numbers:
    if number in birTane:
        continue
    else:
        birTane.append(number)
        
    print(number)
# Out:
# 5
# 10
# 15
# 20

# %% [markdown]
# ### 🌶️ b) Hadi işi biraz daha zorlaştıralım!
#
#
# Şimdiyse senden `numbers` isimli listedeki tekrar eden elemanları `repeatNumbers` adındaki listeye; tekrar etmeyen elemanları `uniqueNumbers`adındaki listeye kopyalayan yazmanı ve listeleri ekrana bastırmanı bekliyoruz
#
# ```
# >Output
# Tekrar Eden Elemanlar: [10, 10, 15, 15, 15, 20, 20, 20, 20]
# Tekrar Etmeyen Elemanlar: [5]
# ```

# %%
numbers=[5,10,10,15,15,15,20,20,20,20]
uniqueNum=[]
repeatNum=[]
for number in numbers:
    if numbers.count(number)==1:
        uniqueNum.append(number)
    else:
        if numbers not in repeatNum:
            repeatNum.append(number)

print("Tekrar eden", repeatNum)
print("Tekrar etmeyen", uniqueNum)
# Out:
# Tekrar eden [10, 10, 15, 15, 15, 20, 20, 20, 20]
# Tekrar etmeyen [5]

# %% [markdown]
# # Problem 3
# sn1 = {1,2,3,4,5}
#
# sn2 = {4,5,6,7,8}
#
#  Verilen 2 adet küme için kesişimlerini, farklarını ve birleşimlerini bulunuz.

# %%
sn1 = {1,2,3,4,5}
sn2 = {4,5,6,7,8}
kesisim = sn1.intersection(sn2)
print("kesişim:",kesisim)

birlesim = sn1.update(sn2)
print("birleşim:",sn1)

farkı = sn1.difference(sn2)
print("farkı:",farkı)
# Out:
# kesişim: {4, 5}
# birleşim: {1, 2, 3, 4, 5, 6, 7, 8}
# farkı: {1, 2, 3}

# %% [markdown]
# # Problem 4
#
# Buradaki işlemlerimizin tamamı stringler içindir. Aşağıda verilecek olan metodlar için kendinizin örnek yaratması gerekmektedir.
#
# Örneğin `upper` için `string` değişkeni oluştururken` k = "BAC"` şeklinde oluşturmayınız. Bunun yerine k değişkenini `k = "bac`" şeklinde oluşturmanız `upper` metodundaki değişimi görebilmeniz için daha iyi olacaktır.
#
# Bütün metodlardaki değişimin gözle görülür şekilde değişimi beklenmektedir.
#
#
# 1- capitalize(), lower(), upper(), swapcase(), title(), replace()
#
# 2- endswith(), startswith(), find(), index(), count()
#
# 3- split(), strip(), join(), islower(), isalpha(), isdigit()
#
#
# Yukarıdaki `string` metodlarındaki değişimleri görebildiğimiz bir program yazınız.

# %%
k = "YetGen Core Python"

print(k.capitalize())

print(k.lower())

print(k.upper())

print(k.swapcase())

print(k.title())

print(k.replace("Core", "ile"))

print("endswith('Python'):", k.endswith('Python'))

print("startswith('YetGen'):", k.startswith('YetGen'))

print("find('Python'):", k.find('Python'))

print("index('Python'):", k.index('Python'))

print("count('o'):", k.count('o'))

print("split():", k.split(" "))

print("strip():", k.strip())

print("islower():", k.islower())

print("isalpha():", "Python".isalpha())

print("isdigit():", k.isdigit())

print("join(['YetGen', 'Core, 'Python']):", ' '.join(['YetGen', 'Core', 'Python']))
# Out:
# Yetgen core python
# yetgen core python
# YETGEN CORE PYTHON
# yETgEN cORE pYTHON
# Yetgen Core Python
# YetGen ile Python
# endswith('Python'): True
# startswith('YetGen'): True
# find('Python'): 12
# index('Python'): 12
# count('o'): 2
# split(): ['YetGen', 'Core', 'Python']
# strip(): YetGen Core Python
# islower(): False
# isalpha(): True
# isdigit(): False
# join(['YetGen', 'Core, 'Python']): YetGen Core Python
